# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_vectors(p_1, p_2, v_1, v_2,):
    plt.quiver(*p_1, *v_1, scale=1, angles='xy', scale_units='xy', color="red", label="v1")
    plt.quiver(*p_2, *v_2, scale=1, angles='xy', scale_units='xy', color="blue", label="v2")
    plt.xlim(-1,1)
    plt.ylim(-1,1)
    plt.legend()
    plt.show()

    print(angle_between(v_1, v_2, degrees=True))
    print("angle_left" if np.cross(v_1, v_2) > 0 else "angle_right")
    print("loc_left" if np.cross(h_vec, v_loc-h_loc) > 0 else "loc_right")


def unit_vector(vector):
    """ Returns the unit vector of the vector.  """
    return vector / np.linalg.norm(vector)

def angle_between(v1, v2, degrees=False):
    angle = np.arccos(np.clip(np.dot(unit_vector(v1), unit_vector(v2)), -1.0, 1.0))
    return np.degrees(angle) if degrees else angle

# %%
h_loc = np.array([0.1, 0.1])
h_vec = np.array([0.5, 0.5])

v_loc = np.array([0.2, 0.3])
v_vec = np.array([0.5, 0.1])

plot_vectors(h_loc, v_loc, h_vec, v_vec)
# Out:
# 33.690067525979806
# angle_right
# loc_left
